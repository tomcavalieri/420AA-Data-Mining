# %%
# %matplotlib inline
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from collections import defaultdict
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
#plt.rcParams['figure.dpi']= 300  #resolution

from collections import defaultdict

# %%
def draw_list(ts_list, attribute, ts_number=1000, time = None , formatter = None):
    if ts_number >= len(ts_list): ts_number = len(ts_list)-1
    fig = plt.figure()
    ax = fig.subplots()
    for ts in ts_list[:ts_number]:
        if time == None: index = list(ts.index.values)
        else: index= ts[time]
        ax.plot(index, ts[attribute])
    ax.set_ylabel(attribute)
    if formatter !=None:
        date_form = DateFormatter(formatter)
        ax.xaxis.set_major_formatter(date_form)
    plt.show()

# %% [markdown]
# # Data Preparation

# %%
time_col = 'date'

attributes = ['date', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy','Weekday']


df=pd.read_csv(r'/Users/Cava/Desktop/University/Data Science & Business Informatics/Data Mining/Advanced Topics and Applications/Project/data/datatraining.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon1=df[df['Weekday']==0][attributes].copy()
tue1=df[df['Weekday']==1][attributes].copy()  #missing part of the day
wed1=df[df['Weekday']==2][attributes].copy() #incompleted too
thu1=df[df['Weekday']==3][attributes].copy()
fri1=df[df['Weekday']==4][attributes].copy()
sat1=df[df['Weekday']==5][attributes].copy()
sun1=df[df['Weekday']==6][attributes].copy()
    
weekdays1 = [thu1,fri1,sat1,sun1,mon1] #I dont want incompleted days, so wednesday and tuesday are excluded



df=pd.read_csv(r'/Users/Cava/Desktop/University/Data Science & Business Informatics/Data Mining/Advanced Topics and Applications/Project/data/datatest2.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())
                                 
mon2=df[df['Weekday']==0][attributes].copy()
tue2=df[df['Weekday']==1][attributes].copy()  #missing part of the day
wed2=df[df['Weekday']==2][attributes].copy() #incompleted too
thu2=df[df['Weekday']==3][attributes].copy()
fri2=df[df['Weekday']==4][attributes].copy()
sat2=df[df['Weekday']==5][attributes].copy()
sun2=df[df['Weekday']==6][attributes].copy()
    
weekdays2 = [thu2,fri2,sat2,sun2,mon2] #I dont want incompleted days, so wednesday and tuesday are excluded

# %% [markdown]
# ## week list

# %%
week_size = 144
week_list = []

week1 = pd.DataFrame()
for day in weekdays1:
    day.sort_values(time_col, inplace=True)#first of all: order
    week1 = week1.append(day, ignore_index=True )    ##a week

week1_list = []
tmp = week1.copy() 
while(len(tmp)>=week_size):
    ts = tmp.sample(week_size)
    ts.sort_values(time_col, inplace=True)
    week1_list.append(ts)
    week_list.append(ts)
    tmp.drop(ts.index, axis=0, inplace=True) #remove the sample just extract

    
week2 = pd.DataFrame()
for day in weekdays2:    
    day.sort_values(time_col, inplace=True)#first of all: order
    week2 = week2.append(day, ignore_index=True)    ##a week
    
week2_list = []
tmp = week2.copy() 
while(len(tmp)>=week_size):
    ts = tmp.sample(week_size)
    ts.sort_values(time_col, inplace=True)
    week2_list.append(ts)
    week_list.append(ts)
    tmp.drop(ts.index, axis=0, inplace=True) #remove the sample just extract

    
random.shuffle(week_list)
draw_list(week_list, 'Temperature', 15, time = time_col ,formatter = '%d')

# %% [markdown]
# ## day_list

# %%
day_list = []
day_size = 120

day1_list=[]
for day in weekdays1:
    day_copy =day.copy()
    day_copy.reset_index(drop=True, inplace=True)
    while (len(day_copy)>= day_size):
        day_copy['time']=day_copy[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
        day_copy['time']=pd.to_datetime(day_copy['time'], format='%H:%M:%S')  #now a date is setted automaticaly for all records
        ts=day_copy.sample(day_size)
        ts.sort_values('time', inplace=True) #necessary to order to be sure
        day_list.append(ts)
        day1_list.append(ts)
        day_copy.drop(ts.index, axis=0, inplace=True) #remove the sample just extra


day2_list = []
for day in weekdays2:
    day_copy =day.copy()
    day_copy.reset_index(drop=True, inplace=True)
    while (len(day_copy)>= day_size):
        day_copy['time']=day_copy[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
        day_copy['time']=pd.to_datetime(day_copy['time'], format='%H:%M:%S')  #now a date is setted automaticaly for all records
        ts=day_copy.sample(day_size)
        ts.sort_values('time', inplace=True) #necessary to order to be sure
        day_list.append(ts)
        day2_list.append(ts)
        day_copy.drop(ts.index, axis=0, inplace=True) #remove the sample just extract


draw_list(day_list, 'Temperature', time = 'time', formatter = '%H')

# %%
from sklearn import preprocessing

ts_list = []
for temp in day_list:
    ts = temp['CO2'].copy()
    ts_list.append(ts)

ts_array = []
ts_size = len(day_list[1])
for ts in ts_list:
    ts_array.append(np.array(ts).reshape(ts_size,))
    
X = np.array(ts_array)

weekend = lambda ts: 'Weekday' if int(ts['Weekday'][ts.index[0]])< 5 else 'Holiday' 
labels = np.array([weekend(ts) for ts in day_list ])

y = preprocessing.LabelEncoder().fit_transform(labels)
plt.figure()
for i, classe in enumerate(['Weekday','Holiday']):
    plt.subplot(2, 1, i + 1)
    for x in X[labels == classe]:
        plt.plot(x, color='C'+str(i), linewidth=0.9)
    plt.title('Class: {}'.format(classe), fontsize=16)

#plt.tight_layout()
plt.subplots_adjust(hspace=1)
plt.show()

# %% [markdown]
# # Data Normalization

# %%
from keras.optimizers import Adagrad
from tslearn.preprocessing import TimeSeriesScalerMinMax

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score
# Out:
# Using Theano backend.

# %%
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
scaler = TimeSeriesScalerMinMax()
X = scaler.fit_transform(X).reshape(X.shape[0], X.shape[1])

# %% [markdown]
# # Data Partitioning

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %% [markdown]
# # Shaplet Classifier

# %%
n_ts, ts_sz = X_train.shape
n_classes = len(set(y))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 84
# ts_sz 120
# n_classes 2
# shapelet_sizes {12: 3}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=200,
                        verbose=1)

# %%
shp_clf.fit(X_train, y_train)
# Out:
# Epoch 1/200
# 84/84 [==============================] - 0s 63us/step - loss: 0.6992 - binary_accuracy: 0.4048 - binary_crossentropy: 0.6865
# Epoch 2/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6991 - binary_accuracy: 0.5476 - binary_crossentropy: 0.6864
# Epoch 3/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6990 - binary_accuracy: 0.7857 - binary_crossentropy: 0.6863
# Epoch 4/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6989 - binary_accuracy: 0.8095 - binary_crossentropy: 0.6862
# Epoch 5/200
# 84/84 [==============================] - 0s 30us/step - loss: 0.6988 - binary_accuracy: 0.8571 - binary_crossentropy: 0.6861
# Epoch 6/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6987 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6860
# Epoch 7/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6986 - binary_accuracy: 0.8810 - binary_crossentropy: 0.6859
# Epoch 8/200
# 84/84 [==============================] - 0s 30us/step - loss: 0.6985 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6858
# Epoch 9/200
# 84/84 [==============================] - 0s 30us/step - loss: 0.6984 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6857
# Epoch 10/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6983 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6856
# Epoch 11/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6982 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6856
# Epoch 12/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6981 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6855
# Epoch 13/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6980 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6854
# Epoch 14/200
# 84/84 [==============================] - 0s 29us/step - loss: 0.6980 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6853
# Epoch 15/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6979 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6852
# Epoch 16/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6978 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6851
# Epoch 17/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6977 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6850
# Epoch 18/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6976 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6849
# Epoch 19/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6975 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6848
# Epoch 20/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6974 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6847
# Epoch 21/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6973 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6846
# Epoch 22/200
# 84/84 [==============================] - 0s 27us/step - loss: 0.6972 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6845
# Epoch 23/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6971 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6845
# Epoch 24/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6970 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6844
# Epoch 25/200
# 84/84 [==============================] - 0s 40us/step - loss: 0.6969 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6843
# Epoch 26/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6968 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6842
# Epoch 27/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6967 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6841
# Epoch 28/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6966 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6840
# Epoch 29/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6966 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6839
# Epoch 30/200
# 84/84 [==============================] - 0s 40us/step - loss: 0.6965 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6838
# Epoch 31/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6964 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6838
# Epoch 32/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6963 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6837
# Epoch 33/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6962 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6836
# Epoch 34/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6961 - binary_accuracy: 0.8571 - binary_crossentropy: 0.6835
# Epoch 35/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6960 - binary_accuracy: 0.8333 - binary_crossentropy: 0.6834
# Epoch 36/200
# 84/84 [==============================] - 0s 27us/step - loss: 0.6959 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6833
# Epoch 37/200
# 84/84 [==============================] - 0s 26us/step - loss: 0.6958 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6832
# Epoch 38/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6958 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6832
# Epoch 39/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6957 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6831
# Epoch 40/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6956 - binary_accuracy: 0.7976 - binary_crossentropy: 0.6830
# Epoch 41/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6955 - binary_accuracy: 0.7976 - binary_crossentropy: 0.6829
# Epoch 42/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6954 - binary_accuracy: 0.7738 - binary_crossentropy: 0.6828
# Epoch 43/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6953 - binary_accuracy: 0.7738 - binary_crossentropy: 0.6828
# Epoch 44/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6952 - binary_accuracy: 0.7738 - binary_crossentropy: 0.6827
# Epoch 45/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6952 - binary_accuracy: 0.7738 - binary_crossentropy: 0.6826
# Epoch 46/200
# 84/84 [==============================] - 0s 29us/step - loss: 0.6951 - binary_accuracy: 0.7619 - binary_crossentropy: 0.6825
# Epoch 47/200
# 84/84 [==============================] - 0s 28us/step - loss: 0.6950 - binary_accuracy: 0.7500 - binary_crossentropy: 0.6824
# Epoch 48/200
# 84/84 [==============================] - 0s 29us/step - loss: 0.6949 - binary_accuracy: 0.7500 - binary_crossentropy: 0.6824
# Epoch 49/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6948 - binary_accuracy: 0.7500 - binary_crossentropy: 0.6823
# Epoch 50/200
# 84/84 [==============================] - 0s 28us/step - loss: 0.6948 - binary_accuracy: 0.7500 - binary_crossentropy: 0.6822
# Epoch 51/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6947 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6821
# Epoch 52/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6946 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6820
# Epoch 53/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6945 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6820
# Epoch 54/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6944 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6819
# Epoch 55/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6943 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6818
# Epoch 56/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6943 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6817
# Epoch 57/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6942 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6817
# Epoch 58/200
# 84/84 [==============================] - 0s 49us/step - loss: 0.6941 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6816
# Epoch 59/200
# 84/84 [==============================] - 0s 40us/step - loss: 0.6940 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6815
# Epoch 60/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6940 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6814
# Epoch 61/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6939 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6814
# Epoch 62/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6938 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6813
# Epoch 63/200
# 84/84 [==============================] - 0s 51us/step - loss: 0.6937 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6812
# Epoch 64/200
# 84/84 [==============================] - 0s 53us/step - loss: 0.6936 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6812
# Epoch 65/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6936 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6811
# Epoch 66/200
# 84/84 [==============================] - 0s 70us/step - loss: 0.6935 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6810
# Epoch 67/200
# 84/84 [==============================] - 0s 60us/step - loss: 0.6934 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6809
# Epoch 68/200
# 84/84 [==============================] - 0s 52us/step - loss: 0.6933 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6809
# Epoch 69/200
# 84/84 [==============================] - 0s 45us/step - loss: 0.6933 - binary_accuracy: 0.6667 - binary_crossentropy: 0.6808
# Epoch 70/200
# 84/84 [==============================] - 0s 62us/step - loss: 0.6932 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6807
# Epoch 71/200
# 84/84 [==============================] - 0s 83us/step - loss: 0.6931 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6807
# Epoch 72/200
# 84/84 [==============================] - 0s 29us/step - loss: 0.6930 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6806
# Epoch 73/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6930 - binary_accuracy: 0.6310 - binary_crossentropy: 0.6805
# Epoch 74/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6929 - binary_accuracy: 0.6310 - binary_crossentropy: 0.6804
# Epoch 75/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6928 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6804
# Epoch 76/200
# 84/84 [==============================] - 0s 45us/step - loss: 0.6928 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6803
# Epoch 77/200
# 84/84 [==============================] - 0s 44us/step - loss: 0.6927 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6802
# Epoch 78/200
# 84/84 [==============================] - 0s 50us/step - loss: 0.6926 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6802
# Epoch 79/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6925 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6801
# Epoch 80/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6925 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6800
# Epoch 81/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6924 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6800
# Epoch 82/200
# 84/84 [==============================] - 0s 44us/step - loss: 0.6923 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6799
# Epoch 83/200
# 84/84 [==============================] - 0s 50us/step - loss: 0.6923 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6798
# Epoch 84/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6922 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6798
# Epoch 85/200
# 84/84 [==============================] - 0s 52us/step - loss: 0.6921 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6797
# Epoch 86/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6921 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6796
# Epoch 87/200
# 84/84 [==============================] - 0s 27us/step - loss: 0.6920 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6796
# Epoch 88/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6919 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6795
# Epoch 89/200
# 84/84 [==============================] - 0s 26us/step - loss: 0.6918 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6794
# Epoch 90/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6918 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6794
# Epoch 91/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6917 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6793
# Epoch 92/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6916 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6793
# Epoch 93/200
# 84/84 [==============================] - 0s 29us/step - loss: 0.6916 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6792
# Epoch 94/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6915 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6791
# Epoch 95/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6914 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6791
# Epoch 96/200
# 84/84 [==============================] - 0s 44us/step - loss: 0.6914 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6790
# Epoch 97/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6913 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6789
# Epoch 98/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6913 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6789
# Epoch 99/200
# 84/84 [==============================] - 0s 51us/step - loss: 0.6912 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6788
# Epoch 100/200
# 84/84 [==============================] - 0s 57us/step - loss: 0.6911 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6788
# Epoch 101/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6911 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6787
# Epoch 102/200
# 84/84 [==============================] - 0s 48us/step - loss: 0.6910 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6786
# Epoch 103/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6909 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6786
# Epoch 104/200
# 84/84 [==============================] - 0s 63us/step - loss: 0.6909 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6785
# Epoch 105/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6908 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6785
# Epoch 106/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6907 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6784
# Epoch 107/200
# 84/84 [==============================] - 0s 28us/step - loss: 0.6907 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6783
# Epoch 108/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6906 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6783
# Epoch 109/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6906 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6782
# Epoch 110/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6905 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6782
# Epoch 111/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6904 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6781
# Epoch 112/200
# 84/84 [==============================] - 0s 40us/step - loss: 0.6904 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6780
# Epoch 113/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6903 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6780
# Epoch 114/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6902 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6779
# Epoch 115/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6902 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6779
# Epoch 116/200
# 84/84 [==============================] - 0s 41us/step - loss: 0.6901 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6778
# Epoch 117/200
# 84/84 [==============================] - 0s 58us/step - loss: 0.6901 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6778
# Epoch 118/200
# 84/84 [==============================] - 0s 30us/step - loss: 0.6900 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6777
# Epoch 119/200
# 84/84 [==============================] - 0s 28us/step - loss: 0.6899 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6777
# Epoch 120/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6899 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6776
# Epoch 121/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6898 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6775
# Epoch 122/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6898 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6775
# Epoch 123/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6897 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6774
# Epoch 124/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6897 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6774
# Epoch 125/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6896 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6773
# Epoch 126/200
# 84/84 [==============================] - 0s 50us/step - loss: 0.6895 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6773
# Epoch 127/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6895 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6772
# Epoch 128/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6894 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6772
# Epoch 129/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6894 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6771
# Epoch 130/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6893 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6771
# Epoch 131/200
# 84/84 [==============================] - 0s 28us/step - loss: 0.6893 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6770
# Epoch 132/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6892 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6770
# Epoch 133/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6892 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6769
# Epoch 134/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6891 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6768
# Epoch 135/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6890 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6768
# Epoch 136/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6890 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6767
# Epoch 137/200
# 84/84 [==============================] - 0s 44us/step - loss: 0.6889 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6767
# Epoch 138/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6889 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6766
# Epoch 139/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6888 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6766
# Epoch 140/200
# 84/84 [==============================] - 0s 61us/step - loss: 0.6888 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6765
# Epoch 141/200
# 84/84 [==============================] - 0s 61us/step - loss: 0.6887 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6765
# Epoch 142/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6887 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6764
# Epoch 143/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6886 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6764
# Epoch 144/200
# 84/84 [==============================] - 0s 57us/step - loss: 0.6886 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6763
# Epoch 145/200
# 84/84 [==============================] - 0s 29us/step - loss: 0.6885 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6763
# Epoch 146/200
# 84/84 [==============================] - 0s 30us/step - loss: 0.6885 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6762
# Epoch 147/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6884 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6762
# Epoch 148/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6883 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6762
# Epoch 149/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6883 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6761
# Epoch 150/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6882 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6761
# Epoch 151/200
# 84/84 [==============================] - 0s 44us/step - loss: 0.6882 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6760
# Epoch 152/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6881 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6760
# Epoch 153/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6881 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6759
# Epoch 154/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6880 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6759
# Epoch 155/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6880 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6758
# Epoch 156/200
# 84/84 [==============================] - 0s 40us/step - loss: 0.6879 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6758
# Epoch 157/200
# 84/84 [==============================] - 0s 59us/step - loss: 0.6879 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6757
# Epoch 158/200
# 84/84 [==============================] - 0s 60us/step - loss: 0.6878 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6757
# Epoch 159/200
# 84/84 [==============================] - 0s 31us/step - loss: 0.6878 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6756
# Epoch 160/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6877 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6756
# Epoch 161/200
# 84/84 [==============================] - 0s 30us/step - loss: 0.6877 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6755
# Epoch 162/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6876 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6755
# Epoch 163/200
# 84/84 [==============================] - 0s 41us/step - loss: 0.6876 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6755
# Epoch 164/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6876 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6754
# Epoch 165/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6875 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6754
# Epoch 166/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6875 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6753
# Epoch 167/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6874 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6753
# Epoch 168/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6874 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6752
# Epoch 169/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6873 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6752
# Epoch 170/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6873 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6751
# Epoch 171/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6872 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6751
# Epoch 172/200
# 84/84 [==============================] - 0s 49us/step - loss: 0.6872 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6751
# Epoch 173/200
# 84/84 [==============================] - 0s 52us/step - loss: 0.6871 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6750
# Epoch 174/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6871 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6750
# Epoch 175/200
# 84/84 [==============================] - 0s 68us/step - loss: 0.6870 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6749
# Epoch 176/200
# 84/84 [==============================] - 0s 27us/step - loss: 0.6870 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6749
# Epoch 177/200
# 84/84 [==============================] - 0s 41us/step - loss: 0.6869 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6748
# Epoch 178/200
# 84/84 [==============================] - 0s 35us/step - loss: 0.6869 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6748
# Epoch 179/200
# 84/84 [==============================] - 0s 41us/step - loss: 0.6869 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6748
# Epoch 180/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6868 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6747
# Epoch 181/200
# 84/84 [==============================] - 0s 42us/step - loss: 0.6868 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6747
# Epoch 182/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6867 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6746
# Epoch 183/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6867 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6746
# Epoch 184/200
# 84/84 [==============================] - 0s 41us/step - loss: 0.6866 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6746
# Epoch 185/200
# 84/84 [==============================] - 0s 46us/step - loss: 0.6866 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6745
# Epoch 186/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6865 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6745
# Epoch 187/200
# 84/84 [==============================] - 0s 25us/step - loss: 0.6865 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6744
# Epoch 188/200
# 84/84 [==============================] - 0s 32us/step - loss: 0.6865 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6744
# Epoch 189/200
# 84/84 [==============================] - 0s 40us/step - loss: 0.6864 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6744
# Epoch 190/200
# 84/84 [==============================] - 0s 36us/step - loss: 0.6864 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6743
# Epoch 191/200
# 84/84 [==============================] - 0s 37us/step - loss: 0.6863 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6743
# Epoch 192/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6863 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6742
# Epoch 193/200
# 84/84 [==============================] - 0s 50us/step - loss: 0.6862 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6742
# Epoch 194/200
# 84/84 [==============================] - 0s 43us/step - loss: 0.6862 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6742
# Epoch 195/200
# 84/84 [==============================] - 0s 49us/step - loss: 0.6862 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6741
# Epoch 196/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6861 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6741
# Epoch 197/200
# 84/84 [==============================] - 0s 39us/step - loss: 0.6861 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6741
# Epoch 198/200
# 84/84 [==============================] - 0s 38us/step - loss: 0.6860 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6740
# Epoch 199/200
# 84/84 [==============================] - 0s 33us/step - loss: 0.6860 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6740
# Epoch 200/200
# 84/84 [==============================] - 0s 34us/step - loss: 0.6860 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6739
# ShapeletModel(max_iter=200, n_shapelets_per_size={12: 3}, verbose=1,
#               weight_regularizer=0.01)

# %%
y_pred = shp_clf.predict(X_test)
# Out:
# 36/36 [==============================] - 0s 19us/step

# %%
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Shaplet-distances-based Classifier

# %%
X_train2 = shp_clf.transform(X_train)
# Out:
# 84/84 [==============================] - 0s 18us/step

# %%
X_train2.shape
# Out:
# (84, 3)

# %%
X_train2
# Out:
# array([[0.00242911, 0.00208577, 0.00333054],
#        [0.0017036 , 0.00173521, 0.0016058 ],
#        [0.02456205, 0.02446858, 0.02801855],
#        [0.00045199, 0.00066377, 0.00093136],
#        [0.00222909, 0.00241414, 0.00364239],
#        [0.00339958, 0.00345514, 0.00444235],
#        [0.009844  , 0.00957961, 0.01016065],
#        [0.00037924, 0.00073149, 0.00072668],
#        [0.0013785 , 0.00175516, 0.00243013],
#        [0.00034762, 0.0006823 , 0.00073719],
#        [0.00119858, 0.00159552, 0.00184457],
#        [0.00095802, 0.00154589, 0.00201376],
#        [0.00095058, 0.00143182, 0.00204943],
#        [0.02284986, 0.02313261, 0.02452207],
#        [0.04739328, 0.04876666, 0.04921512],
#        [0.00155674, 0.00161885, 0.00205711],
#        [0.00047089, 0.00065667, 0.00085405],
#        [0.02107812, 0.02118168, 0.02329564],
#        [0.00043038, 0.00071977, 0.00075495],
#        [0.03930242, 0.03825505, 0.04018847],
#        [0.00038125, 0.00071927, 0.00071632],
#        [0.00092043, 0.00115335, 0.00176123],
#        [0.00036807, 0.00069111, 0.00075429],
#        [0.01838279, 0.01555913, 0.02033836],
#        [0.00048728, 0.00071151, 0.00099403],
#        [0.00083149, 0.00093708, 0.00130195],
#        [0.00036619, 0.00071182, 0.00066247],
#        [0.01855557, 0.01902724, 0.02113775],
#        [0.00067592, 0.00064473, 0.00121809],
#        [0.00054506, 0.00073176, 0.00100415],
#        [0.00036072, 0.00068764, 0.00069149],
#        [0.02729551, 0.02662813, 0.02939374],
#        [0.00039684, 0.00066148, 0.00071229],
#        [0.00174738, 0.00164928, 0.0025616 ],
#        [0.01918324, 0.01943469, 0.02079187],
#        [0.00042562, 0.0007714 , 0.00085911],
#        [0.0010422 , 0.00122065, 0.00110737],
#        [0.00141657, 0.00177812, 0.0025377 ],
#        [0.00272113, 0.00245283, 0.00343867],
#        [0.00039624, 0.00072225, 0.00084845],
#        [0.00038985, 0.00075673, 0.00093335],
#        [0.00299037, 0.00256287, 0.00280594],
#        [0.01882166, 0.01868424, 0.02079876],
#        [0.00034264, 0.00068048, 0.00079045],
#        [0.00043217, 0.0008951 , 0.00110473],
#        [0.0003787 , 0.00071063, 0.00072213],
#        [0.00201496, 0.00187691, 0.00236978],
#        [0.00245945, 0.0023746 , 0.0025133 ],
#        [0.02742607, 0.02654899, 0.0297063 ],
#        [0.0004864 , 0.00065623, 0.00098301],
#        [0.02791054, 0.02665373, 0.02987795],
#        [0.00343941, 0.00338368, 0.00374357],
#        [0.00111521, 0.00146098, 0.00228532],
#        [0.02283804, 0.02230012, 0.024528  ],
#        [0.00041606, 0.00061687, 0.00081554],
#        [0.03709408, 0.03577179, 0.03781561],
#        [0.00203419, 0.00243638, 0.00317927],
#        [0.00166008, 0.00213611, 0.00172038],
#        [0.00034378, 0.00070483, 0.00069712],
#        [0.02158353, 0.0207007 , 0.02302401],
#        [0.01085603, 0.01239071, 0.01301147],
#        [0.004339  , 0.00399234, 0.00430438],
#        [0.00037542, 0.00063858, 0.000782  ],
#        [0.03931268, 0.03906969, 0.04139411],
#        [0.05788543, 0.05618584, 0.06155654],
#        [0.00036232, 0.00070739, 0.00068677],
#        [0.00178098, 0.00234569, 0.00300123],
#        [0.0018976 , 0.00203582, 0.00262494],
#        [0.00252322, 0.00233075, 0.00240898],
#        [0.00154505, 0.00184146, 0.00272289],
#        [0.03600247, 0.03695739, 0.03973324],
#        [0.0305822 , 0.03085215, 0.03347867],
#        [0.0319698 , 0.0320023 , 0.03396045],
#        [0.00040782, 0.00060141, 0.00074461],
#        [0.00160127, 0.00173796, 0.00236328],
#        [0.01180835, 0.01197772, 0.01336752],
#        [0.0003764 , 0.00069109, 0.00068615],
#        [0.00046554, 0.00068455, 0.00098469],
#        [0.00037528, 0.00069585, 0.00068442],
#        [0.03689339, 0.03572605, 0.03957678],
#        [0.0003711 , 0.00068712, 0.00068166],
#        [0.02558453, 0.02546479, 0.02614793],
#        [0.00042479, 0.00057392, 0.00078125],
#        [0.02896672, 0.02791494, 0.02848392]], dtype=float32)

# %%
X_test2 = shp_clf.transform(X_test)
# Out:
# 36/36 [==============================] - 0s 22us/step

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train2, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8888888888888888
# F1-score [0.84615385 0.91304348]
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        14
#            1       0.88      0.95      0.91        22
#
#     accuracy                           0.89        36
#    macro avg       0.90      0.87      0.88        36
# weighted avg       0.89      0.89      0.89        36

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train2, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8333333333333334
# F1-score [0.8        0.85714286]
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80        14
#            1       0.90      0.82      0.86        22
#
#     accuracy                           0.83        36
#    macro avg       0.82      0.84      0.83        36
# weighted avg       0.84      0.83      0.83        36

# %% [markdown]
# # Feature-based Classifier

# %%
import scipy.stats as stats

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
X_train3 = np.array([list(calculate_features(x).values()) for x in X_train])

# %%
X_train3.shape
# Out:
# (84, 13)

# %%
X_train3
# Out:
# array([[ 0.30949501,  0.2121713 ,  0.04501666, ...,  1.45870348,
#          0.66680893,  0.82409722],
#        [ 0.19557929,  0.18429786,  0.0339657 , ...,  1.06121307,
#          2.00288058,  4.33939667],
#        [ 0.40734767,  0.18732423,  0.03509037, ...,  2.17455947,
#          0.63268838,  0.58405625],
#        ...,
#        [ 0.40228198,  0.26408134,  0.06973895, ...,  1.52332603,
#          0.78745016, -0.48305836],
#        [ 0.34139513,  0.34809417,  0.12116955, ...,  0.98075508,
#          0.42456074, -1.51407771],
#        [ 0.36227865,  0.2320522 ,  0.05384822, ...,  1.56119461,
#          0.91516791,  0.10046818]])

# %%
X_test3 = np.array([list(calculate_features(x).values()) for x in X_test])

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train3, y_train)

y_pred = clf.predict(X_test3)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9166666666666666
# F1-score [0.88888889 0.93333333]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.91      0.95      0.93        22
#
#     accuracy                           0.92        36
#    macro avg       0.92      0.91      0.91        36
# weighted avg       0.92      0.92      0.92        36

# %% [markdown]
# # Time Series Classifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
from pyts.classification import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(metric='dtw_sakoechiba')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# # CNN Classifier

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling1D
from keras.layers import Conv1D, Activation, Conv1D, BatchNormalization

# %%
def build_simple_cnn(n_timesteps, n_outputs):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, 1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_cnn = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train_cnn, y_train, test_size=0.2, stratify=y_train)

n_timesteps, n_outputs, n_features = X_train_cnn.shape[1], len(np.unique(y_train_cnn)), 1 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
# Out:
# TIMESTEPS:  120
# N. LABELS:  2

# %%
cnn = build_simple_cnn(n_timesteps, n_outputs)

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 113, 16)           144
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 113, 16)           64
# _________________________________________________________________
# activation_1 (Activation)    (None, 113, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 113, 16)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 109, 32)           2592
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 109, 32)           128
# _________________________________________________________________
# activation_2 (Activation)    (None, 109, 32)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 109, 32)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 107, 64)           6208
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 107, 64)           256
# _________________________________________________________________
# activation_3 (Activation)    (None, 107, 64)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 107, 64)           0
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 9,522
# Trainable params: 9,298
# Non-trainable params: 224
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train_cnn.shape[0]/10, batch_size))

# %%
history_cnn = cnn.fit(X_train_cnn, y_train_cnn, epochs=5, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/5
# 67/67 [==============================] - 0s 2ms/step - loss: 0.6587 - accuracy: 0.5821 - val_loss: 0.6885 - val_accuracy: 0.5882
# Epoch 2/5
#  6/67 [=>............................] - ETA: 0s - loss: 0.5860 - accuracy: 0.5000
# /opt/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5555 - accuracy: 0.7612 - val_loss: 0.6878 - val_accuracy: 0.5882
# Epoch 3/5
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4364 - accuracy: 0.8955 - val_loss: 0.6900 - val_accuracy: 0.5882
# Epoch 4/5
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.9104 - val_loss: 0.6913 - val_accuracy: 0.5882
# Epoch 5/5
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4099 - accuracy: 0.8358 - val_loss: 0.6915 - val_accuracy: 0.5882

# %%
y_pred = np.argmax(cnn.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cnn.evaluate(X_test_cnn, y_test)
# Out:
# 36/36 [==============================] - 0s 694us/step
# [0.6910348335901896, 0.6111111044883728]

# %% [markdown]
# # LSTM Classifier

# %%
from keras.layers import LSTM

# %%
def build_lstm(n_timesteps, n_outputs):
    model = Sequential()
    model.add(LSTM(256, input_shape=(n_timesteps, 1)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm = build_lstm(n_timesteps, n_outputs)

# %%
lstm.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 256)               264192
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 280,770
# Trainable params: 280,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm = cnn.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=mini_batch_size, callbacks=callbacks,
                       validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.8955 - val_loss: 0.6915 - val_accuracy: 0.5882
# Epoch 2/10
# 42/67 [=================>............] - ETA: 0s - loss: 0.2580 - accuracy: 0.9762
# /opt/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.9254 - val_loss: 0.6915 - val_accuracy: 0.5882
# Epoch 3/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2150 - accuracy: 0.9552 - val_loss: 0.6916 - val_accuracy: 0.5882
# Epoch 4/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2024 - accuracy: 0.9701 - val_loss: 0.6918 - val_accuracy: 0.5882
# Epoch 5/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1732 - accuracy: 1.0000 - val_loss: 0.6918 - val_accuracy: 0.5882
# Epoch 6/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1651 - accuracy: 0.9851 - val_loss: 0.6914 - val_accuracy: 0.5882
# Epoch 7/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9403 - val_loss: 0.6917 - val_accuracy: 0.6471
# Epoch 8/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9701 - val_loss: 0.6915 - val_accuracy: 0.4706
# Epoch 9/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1494 - accuracy: 1.0000 - val_loss: 0.6905 - val_accuracy: 0.4118
# Epoch 10/10
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2218 - accuracy: 0.9254 - val_loss: 0.6909 - val_accuracy: 0.5294

# %%
y_pred = np.argmax(lstm.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.3888888888888889
# F1-score [0.56 0.  ]
#               precision    recall  f1-score   support
#
#            0       0.39      1.00      0.56        14
#            1       0.00      0.00      0.00        22
#
#     accuracy                           0.39        36
#    macro avg       0.19      0.50      0.28        36
# weighted avg       0.15      0.39      0.22        36
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
lstm.evaluate(X_test_cnn, y_test)
# Out:
# 36/36 [==============================] - 0s 2ms/step
# /opt/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# [0.6902842322985331, 0.3888888955116272]

# %% [markdown]
# # Multivariate Time Series Classifiers

# %%
from pyts.datasets import load_basic_motions

from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
from sklearn import preprocessing

ts_list = []
for temp in day_list:
    ts = temp[['Temperature','Humidity','CO2','Light','HumidityRatio']].copy()
    ts_list.append(ts)

ts_array = []
ts_size = len(day_list[1])
for ts in ts_list:
    ts_array.append(np.array(ts))
    
X = np.array(ts_array)

X.shape
# Out:
# (120, 120, 5)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %%
scaler = TimeSeriesScalerMinMax()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape, X_test.shape)

unique_elements, counts_elements = np.unique(y_train, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements, counts_elements = np.unique(y_test, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# (84, 120, 5) (36, 120, 5)
# [[ 0  1]
#  [34 50]]
# [[ 0  1]
#  [14 22]]

# %%
n_timesteps, n_outputs, n_features = X_train.shape[1], len(np.unique(y_train)), X_train.shape[2] 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
print("N. FEATURES: ", n_features)
# Out:
# TIMESTEPS:  120
# N. LABELS:  2
# N. FEATURES:  5

# %%
X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers import TimeDistributed
from keras.layers.recurrent import LSTM
from keras.layers import Dense, Conv1D, Conv2D, MaxPool2D, Flatten, Dropout, LeakyReLU, GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
def build_lstm2(n_timesteps, n_outputs, n_features):
    model = Sequential()
    model.add(LSTM(4, input_shape=(n_timesteps, n_features), return_sequences=True, 
                        kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.3))
    
    #1
    for _ in range(2):
        model.add(LSTM(4, kernel_initializer='TruncatedNormal', return_sequences=True))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.04))   

    #2
    model.add(LSTM(32, kernel_initializer='TruncatedNormal', return_sequences=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
    
    #3
    for _ in range(2):
        model.add(Dense(256, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))
    #4
    for _ in range(1):
        model.add(Dense(64, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.7))

    #5
    model.add(Dense(32, kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.4))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm2 = build_lstm2(n_timesteps, n_outputs, n_features)

# %%
lstm2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 120, 4)            160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 120, 4)            16
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 120, 4)            0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 120, 4)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120, 4)            144
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 120, 4)            16
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 120, 4)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 120, 4)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 120, 4)            144
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 120, 4)            16
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 120, 4)            0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 120, 4)            0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                4736
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               8448
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                16448
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 100,626
# Trainable params: 99,322
# Non-trainable params: 1,304
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_lstm2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_lstm2 = lstm2.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                          validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# INFO (theano.gof.compilelock): Waiting for existing lock by process '68230' (I am process '68108')
# INFO (theano.gof.compilelock): To manually release the lock, delete /Users/Cava/.theano/compiledir_Darwin-19.5.0-x86_64-i386-64bit-i386-3.7.6-64/lock_dir
# Train on 67 samples, validate on 17 samples
# Epoch 1/50
# 24/67 [=========>....................] - ETA: 0s - loss: 0.7957 - accuracy: 0.5000
# /opt/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 67/67 [==============================] - 1s 8ms/step - loss: 0.6991 - accuracy: 0.5821 - val_loss: 0.6918 - val_accuracy: 0.5882
# Epoch 2/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.5983 - accuracy: 0.6567 - val_loss: 0.6908 - val_accuracy: 0.5882
# Epoch 3/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.5291 - accuracy: 0.7313 - val_loss: 0.6899 - val_accuracy: 0.5882
# Epoch 4/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.5634 - accuracy: 0.7612 - val_loss: 0.6888 - val_accuracy: 0.5882
# Epoch 5/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3981 - accuracy: 0.8507 - val_loss: 0.6872 - val_accuracy: 0.5882
# Epoch 6/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3262 - accuracy: 0.8955 - val_loss: 0.6853 - val_accuracy: 0.5882
# Epoch 7/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.3345 - accuracy: 0.9104 - val_loss: 0.6836 - val_accuracy: 0.5882
# Epoch 8/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.3863 - accuracy: 0.8657 - val_loss: 0.6820 - val_accuracy: 0.5882
# Epoch 9/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.2227 - accuracy: 0.9701 - val_loss: 0.6807 - val_accuracy: 0.5882
# Epoch 10/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.3117 - accuracy: 0.8955 - val_loss: 0.6794 - val_accuracy: 0.5882
# Epoch 11/50
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3076 - accuracy: 0.8806 - val_loss: 0.6787 - val_accuracy: 0.5882
# Epoch 12/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.2732 - accuracy: 0.8955 - val_loss: 0.6781 - val_accuracy: 0.5882
# Epoch 13/50
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2744 - accuracy: 0.8806 - val_loss: 0.6775 - val_accuracy: 0.5882
# Epoch 14/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.2753 - accuracy: 0.8657 - val_loss: 0.6773 - val_accuracy: 0.5882
# Epoch 15/50
# 67/67 [==============================] - 1s 10ms/step - loss: 0.2918 - accuracy: 0.8657 - val_loss: 0.6775 - val_accuracy: 0.5882
# Epoch 16/50
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2066 - accuracy: 0.9851 - val_loss: 0.6791 - val_accuracy: 0.5882
# Epoch 17/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1839 - accuracy: 0.9403 - val_loss: 0.6804 - val_accuracy: 0.5882
# Epoch 18/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1765 - accuracy: 0.9254 - val_loss: 0.6833 - val_accuracy: 0.5882
# Epoch 19/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.2004 - accuracy: 0.9403 - val_loss: 0.6874 - val_accuracy: 0.5882
# Epoch 20/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1841 - accuracy: 0.9851 - val_loss: 0.6927 - val_accuracy: 0.5882
# Epoch 21/50
# 67/67 [==============================] - 1s 7ms/step - loss: 0.2604 - accuracy: 0.9403 - val_loss: 0.6998 - val_accuracy: 0.5882
# Epoch 22/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1149 - accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.5882
# Epoch 23/50
# 67/67 [==============================] - 1s 7ms/step - loss: 0.2776 - accuracy: 0.9552 - val_loss: 0.7118 - val_accuracy: 0.5882
# Epoch 24/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1982 - accuracy: 0.9403 - val_loss: 0.7157 - val_accuracy: 0.5882
# Epoch 25/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1175 - accuracy: 0.9701 - val_loss: 0.7193 - val_accuracy: 0.5882
# Epoch 26/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1239 - accuracy: 0.9851 - val_loss: 0.7312 - val_accuracy: 0.5882
# Epoch 27/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1592 - accuracy: 0.9851 - val_loss: 0.7476 - val_accuracy: 0.5882
# Epoch 28/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.2213 - accuracy: 0.9254 - val_loss: 0.7560 - val_accuracy: 0.5882
# Epoch 29/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.2295 - accuracy: 0.8806 - val_loss: 0.7642 - val_accuracy: 0.5882
# Epoch 30/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1971 - accuracy: 0.9403 - val_loss: 0.7642 - val_accuracy: 0.5882
# Epoch 31/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1081 - accuracy: 0.9851 - val_loss: 0.7616 - val_accuracy: 0.5882
# Epoch 32/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1926 - accuracy: 0.9104 - val_loss: 0.7581 - val_accuracy: 0.5882
# Epoch 33/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.2107 - accuracy: 0.9403 - val_loss: 0.7506 - val_accuracy: 0.5882
# Epoch 34/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0931 - accuracy: 1.0000 - val_loss: 0.7511 - val_accuracy: 0.5882
# Epoch 35/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.7443 - val_accuracy: 0.5882
# Epoch 36/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0889 - accuracy: 1.0000 - val_loss: 0.7416 - val_accuracy: 0.5882
# Epoch 37/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1062 - accuracy: 0.9701 - val_loss: 0.7348 - val_accuracy: 0.5882
# Epoch 38/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1438 - accuracy: 0.9403 - val_loss: 0.7299 - val_accuracy: 0.5882
# Epoch 39/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0985 - accuracy: 0.9851 - val_loss: 0.7211 - val_accuracy: 0.5882
# Epoch 40/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1779 - accuracy: 0.9254 - val_loss: 0.7141 - val_accuracy: 0.5882
# Epoch 41/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1415 - accuracy: 0.9403 - val_loss: 0.7257 - val_accuracy: 0.5882
# Epoch 42/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1006 - accuracy: 0.9851 - val_loss: 0.7432 - val_accuracy: 0.5882
# Epoch 43/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1891 - accuracy: 0.9403 - val_loss: 0.7630 - val_accuracy: 0.5882
# Epoch 44/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.2768 - accuracy: 0.9104 - val_loss: 0.6891 - val_accuracy: 0.5882
# Epoch 45/50
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1962 - accuracy: 0.9254 - val_loss: 0.6485 - val_accuracy: 0.5882
# Epoch 46/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1867 - accuracy: 0.9552 - val_loss: 0.6259 - val_accuracy: 0.5882
# Epoch 47/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1825 - accuracy: 0.9552 - val_loss: 0.6245 - val_accuracy: 0.5882
# Epoch 48/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.6335 - val_accuracy: 0.5882
# Epoch 49/50
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.6183 - val_accuracy: 0.5882
# Epoch 50/50
# 67/67 [==============================] - 0s 6ms/step - loss: 0.0481 - accuracy: 1.0000 - val_loss: 0.5934 - val_accuracy: 0.5882

# %%
y_pred = np.argmax(lstm2.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train_cnn.shape
# Out:
# (67, 120, 5)

# %%
X_train_cnn2 = X_train_cnn.reshape(X_train_cnn.shape[0], X_train_cnn.shape[1], X_train_cnn.shape[2], 1)
X_val_cnn2 = X_val_cnn.reshape(X_val_cnn.shape[0], X_val_cnn.shape[1], X_val_cnn.shape[2], 1)
X_test_cnn2 = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

X_train_cnn2.shape
# Out:
# (67, 120, 5, 1)

# %%
def build_cnn2(n_timesteps, n_features, n_outputs):
    input_shape = (n_timesteps, n_features, 1)

    model = Sequential()
    
    ks1_first = 3
    ks1_second = 3
    
    ks2_first = 4
    ks2_second = 4
    
    model.add(Conv2D(filters=(3), 
                     kernel_size=(ks1_first, ks1_second),
                     input_shape=input_shape, 
                     padding='same',
                     kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.02))
    
    for _ in range(2):
        model.add(Conv2D(filters=(4), 
                     kernel_size= (ks2_first, ks2_second), 
                         padding='same',
                     kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))  
    
    model.add(Flatten())
    
    for _ in range(4):
        model.add(Dense(64 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.4))
    
    for _ in range(3):
        model.add(Dense(128 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.3))
  
    model.add(Dense(1024 , kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn2 = build_cnn2(n_timesteps, n_features, n_outputs)

# %%
cnn2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 120, 5, 3)         30
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 120, 5, 3)         12
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 120, 5, 3)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 120, 5, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 120, 5, 4)         196
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 120, 5, 4)         16
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 120, 5, 4)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 120, 5, 4)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 120, 5, 4)         260
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 120, 5, 4)         16
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 120, 5, 4)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 120, 5, 4)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2400)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                153664
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               8320
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1024)              132096
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 1024)              4096
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 2050
# =================================================================
# Total params: 348,820
# Trainable params: 345,470
# Non-trainable params: 3,350
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn2 = cnn2.fit(X_train_cnn2, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn2, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9715 - accuracy: 0.5821 - val_loss: 0.6924 - val_accuracy: 0.5882
# /opt/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# Epoch 2/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.8421 - accuracy: 0.5522 - val_loss: 0.6900 - val_accuracy: 0.5882
# Epoch 3/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.7388 - accuracy: 0.6119 - val_loss: 0.6871 - val_accuracy: 0.5882
# Epoch 4/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.7612 - val_loss: 0.6867 - val_accuracy: 0.5882
# Epoch 5/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9580 - accuracy: 0.5821 - val_loss: 0.6860 - val_accuracy: 0.5882
# Epoch 6/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.7015 - val_loss: 0.6852 - val_accuracy: 0.5882
# Epoch 7/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4909 - accuracy: 0.7910 - val_loss: 0.6841 - val_accuracy: 0.5882
# Epoch 8/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3815 - accuracy: 0.8060 - val_loss: 0.6828 - val_accuracy: 0.5882
# Epoch 9/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4232 - accuracy: 0.8209 - val_loss: 0.6819 - val_accuracy: 0.5882
# Epoch 10/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4175 - accuracy: 0.8358 - val_loss: 0.6806 - val_accuracy: 0.5882
# Epoch 11/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8358 - val_loss: 0.6804 - val_accuracy: 0.5882
# Epoch 12/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1993 - accuracy: 0.9403 - val_loss: 0.6809 - val_accuracy: 0.5882
# Epoch 13/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.8955 - val_loss: 0.6805 - val_accuracy: 0.5882
# Epoch 14/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2961 - accuracy: 0.8657 - val_loss: 0.6794 - val_accuracy: 0.5882
# Epoch 15/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2617 - accuracy: 0.8955 - val_loss: 0.6780 - val_accuracy: 0.5882
# Epoch 16/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2305 - accuracy: 0.8955 - val_loss: 0.6772 - val_accuracy: 0.5882
# Epoch 17/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2134 - accuracy: 0.9104 - val_loss: 0.6758 - val_accuracy: 0.5882
# Epoch 18/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1903 - accuracy: 0.9552 - val_loss: 0.6747 - val_accuracy: 0.5882
# Epoch 19/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3125 - accuracy: 0.9104 - val_loss: 0.6742 - val_accuracy: 0.5882
# Epoch 20/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3765 - accuracy: 0.8806 - val_loss: 0.6735 - val_accuracy: 0.5882
# Epoch 21/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3789 - accuracy: 0.8657 - val_loss: 0.6705 - val_accuracy: 0.5882
# Epoch 22/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9254 - val_loss: 0.6678 - val_accuracy: 0.5882
# Epoch 23/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3603 - accuracy: 0.8358 - val_loss: 0.6692 - val_accuracy: 0.5882
# Epoch 24/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2794 - accuracy: 0.8955 - val_loss: 0.6691 - val_accuracy: 0.5882
# Epoch 25/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4031 - accuracy: 0.8806 - val_loss: 0.6664 - val_accuracy: 0.5882
# Epoch 26/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.7761 - val_loss: 0.6632 - val_accuracy: 0.5882
# Epoch 27/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2959 - accuracy: 0.8507 - val_loss: 0.6576 - val_accuracy: 0.5882
# Epoch 28/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4440 - accuracy: 0.8209 - val_loss: 0.6490 - val_accuracy: 0.5882
# Epoch 29/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1725 - accuracy: 0.9552 - val_loss: 0.6360 - val_accuracy: 0.5882
# Epoch 30/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2722 - accuracy: 0.8955 - val_loss: 0.6140 - val_accuracy: 0.5882
# Epoch 31/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.9254 - val_loss: 0.5959 - val_accuracy: 0.5882
# Epoch 32/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3921 - accuracy: 0.8657 - val_loss: 0.5950 - val_accuracy: 0.5882
# Epoch 33/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3235 - accuracy: 0.9254 - val_loss: 0.5968 - val_accuracy: 0.5882
# Epoch 34/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3301 - accuracy: 0.9104 - val_loss: 0.5786 - val_accuracy: 0.5882
# Epoch 35/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1843 - accuracy: 0.9403 - val_loss: 0.5562 - val_accuracy: 0.5882
# Epoch 36/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.9104 - val_loss: 0.5278 - val_accuracy: 0.5882
# Epoch 37/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3562 - accuracy: 0.8806 - val_loss: 0.5357 - val_accuracy: 0.8235
# Epoch 38/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2633 - accuracy: 0.9104 - val_loss: 0.5157 - val_accuracy: 0.8824
# Epoch 39/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2848 - accuracy: 0.8806 - val_loss: 0.4902 - val_accuracy: 0.8235
# Epoch 40/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3476 - accuracy: 0.8657 - val_loss: 0.4731 - val_accuracy: 0.7647
# Epoch 41/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1485 - accuracy: 0.9701 - val_loss: 0.4496 - val_accuracy: 0.6471
# Epoch 42/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2698 - accuracy: 0.8657 - val_loss: 0.4240 - val_accuracy: 0.7059
# Epoch 43/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9701 - val_loss: 0.4009 - val_accuracy: 0.8824
# Epoch 44/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2892 - accuracy: 0.9403 - val_loss: 0.3808 - val_accuracy: 0.8824
# Epoch 45/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2011 - accuracy: 0.9403 - val_loss: 0.3793 - val_accuracy: 0.8824
# Epoch 46/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.4285 - accuracy: 0.8507 - val_loss: 0.3894 - val_accuracy: 0.8824
# Epoch 47/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.5217 - accuracy: 0.8209 - val_loss: 0.4788 - val_accuracy: 0.8824
# Epoch 48/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.1940 - accuracy: 0.9851 - val_loss: 0.5211 - val_accuracy: 0.8824
# Epoch 49/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.3263 - accuracy: 0.8955 - val_loss: 0.4746 - val_accuracy: 0.8824
# Epoch 50/50
# 67/67 [==============================] - 0s 3ms/step - loss: 0.2772 - accuracy: 0.8955 - val_loss: 0.4105 - val_accuracy: 0.9412

# %%
y_pred = np.argmax(cnn2.predict(X_test_cnn2), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8888888888888888
# F1-score [0.83333333 0.91666667]
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83        14
#            1       0.85      1.00      0.92        22
#
#     accuracy                           0.89        36
#    macro avg       0.92      0.86      0.88        36
# weighted avg       0.91      0.89      0.88        36

# %%
def build_cnn3(n_timesteps, n_outputs, n_features):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, n_features)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn3 = build_cnn3(n_timesteps, n_outputs, n_features)

# %%
cnn3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 113, 16)           656
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 113, 16)           64
# _________________________________________________________________
# activation_4 (Activation)    (None, 113, 16)           0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 113, 16)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 109, 32)           2592
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 109, 32)           128
# _________________________________________________________________
# activation_5 (Activation)    (None, 109, 32)           0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 109, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 107, 64)           6208
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 107, 64)           256
# _________________________________________________________________
# activation_6 (Activation)    (None, 107, 64)           0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 107, 64)           0
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 10,034
# Trainable params: 9,810
# Non-trainable params: 224
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn3 = cnn3.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.7111 - accuracy: 0.4328 - val_loss: 0.6794 - val_accuracy: 0.5882
# Epoch 2/50
#  8/67 [==>...........................] - ETA: 0s - loss: 0.6072 - accuracy: 1.0000
# /opt/anaconda3/lib/python3.7/site-packages/theano/tensor/subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 67/67 [==============================] - 0s 2ms/step - loss: 0.5890 - accuracy: 0.8806 - val_loss: 0.6580 - val_accuracy: 0.5882
# Epoch 3/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.8955 - val_loss: 0.6216 - val_accuracy: 0.5882
# Epoch 4/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.9552 - val_loss: 0.5795 - val_accuracy: 0.5882
# Epoch 5/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.9552 - val_loss: 0.5409 - val_accuracy: 0.5882
# Epoch 6/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.9403 - val_loss: 0.5123 - val_accuracy: 0.5882
# Epoch 7/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1855 - accuracy: 0.9851 - val_loss: 0.4797 - val_accuracy: 0.5882
# Epoch 8/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1598 - accuracy: 0.9851 - val_loss: 0.4557 - val_accuracy: 0.5882
# Epoch 9/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.5882
# Epoch 10/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 0.4221 - val_accuracy: 0.5882
# Epoch 11/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.5882
# Epoch 12/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.5882
# Epoch 13/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 0.3969 - val_accuracy: 0.6471
# Epoch 14/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 1.0000 - val_loss: 0.3837 - val_accuracy: 0.6471
# Epoch 15/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.6471
# Epoch 16/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 0.3596 - val_accuracy: 0.8824
# Epoch 17/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.3457 - val_accuracy: 0.9412
# Epoch 18/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.3408 - val_accuracy: 1.0000
# Epoch 19/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.3339 - val_accuracy: 1.0000
# Epoch 20/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.3404 - val_accuracy: 1.0000
# Epoch 21/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.3396 - val_accuracy: 1.0000
# Epoch 22/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.3269 - val_accuracy: 1.0000
# Epoch 23/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9851 - val_loss: 0.3117 - val_accuracy: 1.0000
# Epoch 24/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 1.0000
# Epoch 25/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9701 - val_loss: 0.2544 - val_accuracy: 1.0000
# Epoch 26/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9851 - val_loss: 0.1904 - val_accuracy: 1.0000
# Epoch 27/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0932 - accuracy: 0.9701 - val_loss: 0.2163 - val_accuracy: 0.9412
# Epoch 28/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9412
# Epoch 29/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0597 - accuracy: 0.9851 - val_loss: 0.1872 - val_accuracy: 1.0000
# Epoch 30/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 31/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 1.0000
# Epoch 32/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 1.0000
# Epoch 33/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 1.0000
# Epoch 34/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 35/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9701 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 36/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9851 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 37/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 38/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 39/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9851 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 40/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0597 - accuracy: 0.9701 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 41/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 1.0000
# Epoch 42/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 43/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 1.0000
# Epoch 44/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 1.0000
# Epoch 45/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 46/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 47/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 1.0000
# Epoch 48/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 49/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 1.0000
# Epoch 50/50
# 67/67 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9851 - val_loss: 0.0255 - val_accuracy: 1.0000

# %%
y_pred = np.argmax(cnn3.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.multivariate.classification.MultivariateClassifier.html#pyts.multivariate.classification.MultivariateClassifier
